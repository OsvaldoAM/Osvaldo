# %% [markdown]
# ### Linkedin - Empresas em que trabalham os meus contatos

# %%
# !pip install PrettyTable
# Out:
# Collecting PrettyTable
#   Downloading https://files.pythonhosted.org/packages/ef/30/4b0746848746ed5941f052479e7c23d2b56d174b82f4fd34a25e389831f5/prettytable-0.7.2.tar.bz2
# Building wheels for collected packages: PrettyTable
#   Running setup.py bdist_wheel for PrettyTable: started
#   Running setup.py bdist_wheel for PrettyTable: finished with status 'done'
#   Stored in directory: C:\Users\Osvaldo Machado\AppData\Local\pip\Cache\wheels\80\34\1c\3967380d9676d162cb59513bd9dc862d0584e045a162095606
# Successfully built PrettyTable
# Installing collected packages: PrettyTable
# Successfully installed PrettyTable-0.7.2
# You are using pip version 9.0.3, however version 18.0 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# !pip install nltk
# Out:
# Collecting nltk
#   Downloading https://files.pythonhosted.org/packages/50/09/3b1755d528ad9156ee7243d52aa5cd2b809ef053a0f31b53d92853dd653a/nltk-3.3.0.zip (1.4MB)
# Requirement already satisfied: six in c:\programdata\miniconda3\lib\site-packages (from nltk)
# Building wheels for collected packages: nltk
#   Running setup.py bdist_wheel for nltk: started
#   Running setup.py bdist_wheel for nltk: finished with status 'done'
#   Stored in directory: C:\Users\Osvaldo Machado\AppData\Local\pip\Cache\wheels\d1\ab\40\3bceea46922767e42986aef7606a600538ca80de6062dc266c
# Successfully built nltk
# Installing collected packages: nltk
# Successfully installed nltk-3.3
# You are using pip version 9.0.3, however version 18.0 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
#CSV_FILE = '/Users/fabiola/Desktop/PUC/extracao-dados-web-sociais/linkedin/Connections.csv'
CSV_FILE = 'C:/Users/Osvaldo Machado/Desktop/RECUPERAÇÃO DA INFORMAÇÃO/AulaSabado/Connections_Osvaldo.csv'

# %%
from prettytable import PrettyTable
import sys
import nltk
import csv


# Handle any known abbreviations,
# strip off common suffixes, etc.

transforms = [(', Inc.', ''), (', Inc', ''), (', LLC', ''), (', LLP', '')]

csvReader = csv.DictReader(open(CSV_FILE,encoding='utf8'), delimiter=',', quotechar='"')
contacts = [row for row in csvReader]
companies = [c['Company'].strip() for c in contacts if c['Company'].strip() != '']

for i in range(len(companies)):
    for transform in transforms:
        companies[i] = companies[i].replace(*transform)

ufu = 'Universidade Federal de Uberlândia'      
iftm = 'Instituto Federal de Educação, Ciência e Tecnologia do Triângulo Mineiro'
puc = 'Pontifícia Universidade Católica de Minas Gerais'
zup = 'Zup Innovation'
standardize = [('Federal University of Uberlandia', ufu), 
               ('UFU - Universidade Federal de Uberlândia', ufu), 
               ('Universidade Federal de Uberlândia - UFU', ufu), 
               ('IFTM - Inst. Fed. de Educação, Ciência e Tecnologia do Triângulo Mineiro', iftm),
               ('Federal University of Uberlândia',ufu),
               ('Universidade Federal de Uberlandia',ufu),
               ('Instituto Federal de Minas Gerais',iftm),
               ('Instituto Federal Minas Gerais',iftm),
               ('UFU',ufu),
               ('PUC Minas',puc),
               ('Zup It Innovation',zup),
               ('Zup - Connect & Transform',zup)
              ]
for i in range(len(companies)):
    for standard in standardize:
        companies[i] = companies[i].replace(standard[0],standard[1])

        
        
pt = PrettyTable(['Company', 'Freq'])

pt.align['Company'] = 'l'
fdist = nltk.FreqDist(companies)
[pt.add_row([company, freq]) for (company, freq) in fdist.items() if freq > 1]
pt = pt.get_string(sortby="Freq", reversesort=True)
print(pt)
# Out:
# +---------------------------------------------+------+
# | Company                                     | Freq |
# +---------------------------------------------+------+
# | everis                                      |  75  |
# | Zup Innovation                              |  47  |
# | Softbox - Soluções Inteligentes em TI       |  19  |
# | Algar Tech                                  |  14  |
# | Cedro Technologies                          |  13  |
# | Universidade Federal de Uberlândia          |  10  |
# | TQI +Tecnologia +Qualidade +Inovação        |  10  |
# | Kyros Tecnologia                            |  10  |
# | ValeCard                                    |  9   |
# | TQI Consultoria                             |  9   |
# | Algar Telecom                               |  9   |
# | Sankhya Gestão de Negócios                  |  8   |
# | eNe Soluções                                |  6   |
# | TQI - Technology and Quality on Information |  5   |
# | TIM Brasil                                  |  5   |
# | Martins                                     |  4   |
# | Cargill                                     |  4   |
# | Callink Servicos de Call Center             |  4   |
# | Tribanco                                    |  3   |
# | Social Bank                                 |  3   |
# | Neppo Tecnologia da Informação              |  3   |
# | Landix Sistemas                             |  3   |
# | media-core®                                 |  2   |
# | iVendas - Gestão Inteligente                |  2   |
# | everis Uberlandia                           |  2   |
# | Zeus Agrotech                               |  2   |
# | Verity Group                                |  2   |
# | Up Brasil                                   |  2   |
# | Unimed Uberlândia                           |  2   |
# | Sensix Inovações                            |  2   |
# | Scopus Soluções em TI                       |  2   |
# | Projetas Soluções Integradas                |  2   |
# | OpenK Tecnologia                            |  2   |
# | Nidera                                      |  2   |
# | NTT DATA BRASIL                             |  2   |
# | Monsanto Company                            |  2   |
# | Hub Fintech                                 |  2   |
# | Energisa                                    |  2   |
# | Cerveja Templária                           |  2   |
# | CI&T                                        |  2   |
# | Banco Santander                             |  2   |
# | Autônomo                                    |  2   |
# +---------------------------------------------+------+

# %% [markdown]
# ### Linkedin - Cargos que ocupam os meus contatos

# %%
import sys
import nltk
import csv
from prettytable import PrettyTable

professor = 'Professor de Ensino Superior'
professor_basico = 'Professor'
analista_ti = 'Analista de Sistemas'
engenheiro_sw = 'Engenheiro de Software'
transforms = [
    ('Sr.', 'Senior'),
    ('Sr', 'Senior'),
    ('Jr.', 'Junior'),
    ('Jr', 'Junior'),
    ('CEO', 'Chief Executive Officer'),
    ('COO', 'Chief Operating Officer'),
    ('CTO', 'Chief Technology Officer'),
    ('CFO', 'Chief Finance Officer'),
    ('VP', 'Vice President'),
    ('Full Professor',professor),
    ('Professor Dedicação Exclusiva',professor),
    ('Professor Adjunto nível A',professor),
    ('Associate Professor',professor),
    ('Full Time Professor',professor),
    ('Professora Assistente',professor),
    ('Professor adjunto',professor),
    ('Professor do Magistério Superior',professor),
    ('Professora Adjunto',professor),
    ('Professora',professor),
    ('Adjunct Professor',professor),
    ('Professor de Ensino Superior',professor),
    ('Docente',professor_basico),
    #('Professor',professor_basico),
    ('Analista de TI',analista_ti),
    ('Systems Analyst',analista_ti),
    ('Analista de Sistemas, Especialista',analista_ti),
    ('Analista de TI - Administradora Siebel',analista_ti),
    ('Senior System Development Analyst C++',analista_ti),
    ('Analista Desenvolvedor de Sistemas',analista_ti),
    ('Analista de sistemas',analista_ti),
    ('Analista de Sistemas Especialista',analista_ti),
    ('System Analyst and Senior Full-Stack Developer',analista_ti),
    ('Analista de TI Pleno',analista_ti),
    ('Information Technology Analyst',analista_ti),
    ('Analista de sistema',analista_ti),
    ('Desenvolvedor e Analista de Sistemas',analista_ti),
    ('Analista Programador',analista_ti),
    ('Analista de Desenvolvimento de Sistemas',analista_ti),
    ('Analista de desenvolvimento de software',analista_ti),
    ('Analista de Tecnologia da Informação',analista_ti),
    ('System Analyst',analista_ti),
    ('Software Engineer',engenheiro_sw),
    ('Software Engineering',engenheiro_sw),
    ('System Software Engineer',engenheiro_sw),
    ('Software engineer',engenheiro_sw),
    ('Senior Software Engineer Team Lead',engenheiro_sw),
    ('Senior C++ Software Engineer',engenheiro_sw),
    ('Engenheiro de software',engenheiro_sw),
    ('Senior Engenheiro de Software',engenheiro_sw),
    ('System Engenheiro de Software',engenheiro_sw),
    ('Software Developer',engenheiro_sw),
    ('Desenvolvedor',engenheiro_sw),
    ('Analista Desenvolvedor',engenheiro_sw),
    ('Analista Engenheiro de Software',engenheiro_sw),
    ('Software Development Engineer',engenheiro_sw),
    ('Senior C++ Engenheiro de Software',engenheiro_sw),
    ('Engenheiro de Software na ZUP',engenheiro_sw),
    ('Staff Engenheiro de Software',engenheiro_sw)
    
    ]

csvReader = csv.DictReader(open(CSV_FILE,encoding='utf8'), delimiter=',', quotechar='"')
contacts = [row for row in csvReader]

# Read in a list of titles and split apart
# any combined titles like "President/CEO"
# Other variations could be handled as well such
# as "President & CEO", "President and CEO", etc.

titles = []
for contact in contacts:
    titles.extend([t.strip() for t in contact['Position'].split('/')
                  if contact['Position'].strip() != ''])

# Replace common/known abbreviations

for i in range(len(titles)):
    for transform in transforms:
        titles[i] = titles[i].replace(*transform)

# Print out a table of titles sorted by frequency

pt = PrettyTable(['Position', 'Freq'])
pt.align['Position'] = 'l'
titles_fdist = nltk.FreqDist(titles)
[pt.add_row([title, freq]) for (title, freq) in titles_fdist.items() if freq > 1]
pt = pt.get_string(sortby="Freq", reversesort=True)
print(pt)

# Print out a table of tokens sorted by frequency

tokens = []
for title in titles:
    tokens.extend([t.strip(',') for t in title.split()])
pt = PrettyTable(['Token', 'Freq'])
pt.align['Token'] =  'l'
tokens_fdist = nltk.FreqDist(tokens)
[pt.add_row([token, freq]) for (token, freq) in tokens_fdist.items() if freq > 1
 and len(token) > 2]
pt = pt.get_string(sortby="Freq", reversesort=True)
print(pt)
# Out:
# +-------------------------------------+------+
# | Position                            | Freq |
# +-------------------------------------+------+
# | Analista de Sistemas                |  33  |
# | Engenheiro de Software              |  26  |
# | Programador                         |  6   |
# | Analista de Recursos Humanos        |  6   |
# | Professor de Ensino Superior        |  5   |
# | Senior Specialist                   |  4   |
# | Programmer                          |  4   |
# | Estagiário                          |  4   |
# | Engenheiro de Software Pleno        |  4   |
# | Analista de desenvolvimento         |  4   |
# | Gerente de Projetos                 |  3   |
# | Engenheiro de Software Java         |  3   |
# | Coordenador                         |  3   |
# | Chief Executive Officer             |  3   |
# | Business Intelligence Developer     |  3   |
# | Business Intelligence               |  3   |
# | Assistente administrativo           |  3   |
# | Arquiteto de software               |  3   |
# | Analista de testes                  |  3   |
# | Agile Master                        |  3   |
# | Software Architect                  |  2   |
# | Senior Engenheiro de Software       |  2   |
# | Scrum master                        |  2   |
# | Proprietário                        |  2   |
# | Professor Adjunto                   |  2   |
# | Professor                           |  2   |
# | Product Owner                       |  2   |
# | Mobile Developer                    |  2   |
# | Líder de equipe                     |  2   |
# | Líder de Projetos                   |  2   |
# | Front-End Developer                 |  2   |
# | Engenheiro de Software de front-end |  2   |
# | Engenheiro de Software Full Stack   |  2   |
# | Engenheiro de Software .Net         |  2   |
# | Developer                           |  2   |
# | Coordenadora de Recursos Humanos    |  2   |
# | Consultor de vendas                 |  2   |
# | Centers Leader Developer            |  2   |
# | Business Intelligence Analyst       |  2   |
# | Back-end Developer                  |  2   |
# | Analista financeiro                 |  2   |
# | Analista de suporte técnico         |  2   |
# | Analista de suporte                 |  2   |
# | Analista de recursos humanos        |  2   |
# | Analista de processos               |  2   |
# | Analista de negócios                |  2   |
# | Analista de Talentos Humanos        |  2   |
# | Analista de Sistemas Pleno          |  2   |
# | Analista de Sistemas Júnior         |  2   |
# | Analista de Qualidade               |  2   |
# | Analista de Desenvolvimento         |  2   |
# | Analista de Business Intelligence   |  2   |
# | Analista de Billing                 |  2   |
# +-------------------------------------+------+
# +-----------------+------+
# | Token           | Freq |
# +-----------------+------+
# | Analista        | 126  |
# | Software        |  64  |
# | Engenheiro      |  63  |
# | Sistemas        |  43  |
# | Developer       |  25  |
# | Gerente         |  24  |
# | Business        |  20  |
# | Senior          |  18  |
# | Analyst         |  17  |
# | Leader          |  16  |
# | Intelligence    |  16  |
# | Humanos         |  15  |
# | Programador     |  13  |
# | Coordenador     |  13  |
# | Professor       |  12  |
# | Consultor       |  12  |
# | Recursos        |  10  |
# | Pleno           |  10  |
# | Líder           |  9   |
# | software        |  8   |
# | Sênior          |  8   |
# | Operações       |  8   |
# | Junior          |  8   |
# | Java            |  8   |
# | Front-End       |  8   |
# | Especialista    |  8   |
# | Diretor         |  8   |
# | Chief           |  8   |
# | negócios        |  7   |
# | desenvolvimento |  7   |
# | Projetos        |  7   |
# | Officer         |  7   |
# | Master          |  7   |
# | Desenvolvimento |  7   |
# | Coordenadora    |  7   |
# | Arquiteto       |  7   |
# | testes          |  6   |
# | Técnico         |  6   |
# | Talentos        |  6   |
# | Superior        |  6   |
# | Specialist      |  6   |
# | Estagiário      |  6   |
# | Ensino          |  6   |
# | Data            |  6   |
# | Architect       |  6   |
# | vendas          |  5   |
# | suporte         |  5   |
# | projetos        |  5   |
# | and             |  5   |
# | administrativo  |  5   |
# | System          |  5   |
# | Supervisor      |  5   |
# | Scrum           |  5   |
# | Mobile          |  5   |
# | Executive       |  5   |
# | Assistente      |  5   |
# | Analytics       |  5   |
# | sênior          |  4   |
# | humanos         |  4   |
# | Vendas          |  4   |
# | Sócio           |  4   |
# | Programmer      |  4   |
# | Processos       |  4   |
# | Planejamento    |  4   |
# | Manager         |  4   |
# | Júnior          |  4   |
# | Executivo       |  4   |
# | Center          |  4   |
# | Auxiliar        |  4   |
# | Administrativo  |  4   |
# | técnico         |  3   |
# | sistemas        |  3   |
# | recursos        |  3   |
# | processos       |  3   |
# | júnior          |  3   |
# | iOS             |  3   |
# | front-end       |  3   |
# | equipe          |  3   |
# | Team            |  3   |
# | Suporte         |  3   |
# | Service         |  3   |
# | Qualidade       |  3   |
# | Produção        |  3   |
# | Product         |  3   |
# | Owner           |  3   |
# | Operations      |  3   |
# | Operating       |  3   |
# | Negócios        |  3   |
# | Inovação        |  3   |
# | Founder         |  3   |
# | Agile           |  3   |
# | Administrador   |  3   |
# | web             |  2   |
# | qualidade       |  2   |
# | proprietário    |  2   |
# | master          |  2   |
# | financeiro      |  2   |
# | end             |  2   |
# | empresarial     |  2   |
# | Web             |  2   |
# | Trainee         |  2   |
# | Testes          |  2   |
# | Test            |  2   |
# | Tecnologia      |  2   |
# | Stack           |  2   |
# | Sales           |  2   |
# | SQL             |  2   |
# | Representante   |  2   |
# | Proprietário    |  2   |
# | Projetista      |  2   |
# | Produto         |  2   |
# | People          |  2   |
# | PMO             |  2   |
# | Lead            |  2   |
# | Investimentos   |  2   |
# | Infraestrutura  |  2   |
# | Informações     |  2   |
# | III             |  2   |
# | Gestão          |  2   |
# | Gerenciais      |  2   |
# | Full            |  2   |
# | Financial       |  2   |
# | Financeiro      |  2   |
# | Engineer        |  2   |
# | Encarregado     |  2   |
# | Eletricista     |  2   |
# | Director        |  2   |
# | Development     |  2   |
# | DevOps          |  2   |
# | Database        |  2   |
# | Dados           |  2   |
# | Controle        |  2   |
# | Consultora      |  2   |
# | Consultant      |  2   |
# | Co-Founder      |  2   |
# | Chefe           |  2   |
# | Centers         |  2   |
# | CRM             |  2   |
# | Brazil          |  2   |
# | Billing         |  2   |
# | Big             |  2   |
# | Back-end        |  2   |
# | Android         |  2   |
# | Advogada        |  2   |
# | Adjunto         |  2   |
# | .Net            |  2   |
# | .NET            |  2   |
# +-----------------+------+

# %% [markdown]
# ### Linkedin - Clusterizando meus contatos por cargos

# %%
# -*- coding: utf-8 -*-

import sys
import csv
from nltk.metrics.distance import masi_distance
from nltk.metrics.distance import jaccard_distance


DISTANCE_THRESHOLD = 0.67
DISTANCE = jaccard_distance

#DISTANCE_THRESHOLD = 0.2
#DISTANCE = masi_distance


def cluster_contacts_by_title(csv_file):
   

    #separators = ['/', 'and', '&', 'de', '-', 'e', ' ']
    separators = ['/', 'and', '&', '-', 'de']

    csvReader = csv.DictReader(open(csv_file,encoding='utf8'), delimiter=',', quotechar='"')
    contacts = [row for row in csvReader]

    # Normalize and/or replace known abbreviations
    # and build up list of common titles

    all_titles = []
    for i in range(len(contacts)):
        if contacts[i]['Position'] == '':
            contacts[i]['Position'] = ['']
            continue
        titles = [contacts[i]['Position']]
        for title in titles:
            for seperator in separators:
                if title.find(seperator) >= 0:
                    if title in titles:
                        titles.remove(title)
                    titles.extend([title.strip() for title in title.split(seperator)
                                   if title.strip() != ''])

        for transform in transforms:
            titles = [title.replace(*transform) for title in titles]
        contacts[i]['Position'] = titles
        all_titles.extend(titles)

    all_titles = list(set(all_titles))

    clusters = {}
    for title1 in all_titles:
        clusters[title1] = []
        for title2 in all_titles:
            if title2 in clusters[title1] or title2 in clusters and title1 \
                in clusters[title2]:
                continue
            distance = DISTANCE(set(title1.split()), set(title2.split()))
            ##print(distance, set(title1.split()), set(title2.split()))
            if distance < DISTANCE_THRESHOLD:
                clusters[title1].append(title2)


    clusters = [clusters[title] for title in clusters if len(clusters[title]) > 1]
    
    # Round up contacts who are in these clusters and group them together

    clustered_contacts = {}
    for cluster in clusters:
        clustered_contacts[tuple(cluster)] = []
        for contact in contacts:
            for title in contact['Position']:
                if title in cluster:
                    clustered_contacts[tuple(cluster)].append('%s %s.'
                                                              % (contact['First Name'], contact['Last Name'][0]))

    return clustered_contacts


if __name__ == '__main__':
    clustered_contacts = cluster_contacts_by_title(CSV_FILE)

    for titles in clustered_contacts:
        common_titles_heading = 'Common Positions: ' + ', '.join(titles)
        
        descriptive_terms = set(titles[0].split())
        for title in titles:
            descriptive_terms.intersection_update(set(title.split()))
        descriptive_terms_heading = 'Descriptive Terms: ' \
                                    + ', '.join(descriptive_terms)
        print(descriptive_terms_heading)
        print('-' * max(len(descriptive_terms_heading), len(common_titles_heading)))
        print('\n'.join(clustered_contacts[titles]))
        print()
# Out:
# Descriptive Terms:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Rodolfo M.
# Thiago Willian A.
# Renato Dalmo L.
# Rodrigo F.
# Paulo V.
# Nathália R.
# Edilene C.
# Fabiano D.
# Mônica d.
# Jerry G.
# Fernanda B.
# Jakeline B.
# Kele M.
# Warla  L.
# Danilo N.
# Lucas R.
# Thais R.
# Diego H.
# Tarcisio M.
# Rafael B.
# Arlindo J.
# Matheus F.
# Gabriel E.
# Luiz F.
# Laura M.
# Matheus L.
# Arthur D.
# Vagner A.
# Vitor Soares C.
# Andreia V.
# Clayton M.
# Clayton M.
# Hellen C.
# Humberto C.
# Juliana F.
# Rondinele S.
# Diego M.
# Isaac R.
# Marvin  B.
# Bruno Q.
# Matheus D.
# Vander G.
# Layson D.
# Vítor B.
# Juliana V.
# Claudia E.
# Alex D.
# João T.
# João Paulo M.
# Nina Bárbara d.
# Melissa M.
# Marcos M.
# Jerveson L.
# Juliana B.
# Roger S.
# Samuel R.
# Mayara M.
# Roberto R.
# Analice S.
# João M.
# Nayara M.
# Rafael R.
# Thiago R.
# Marianna C.
# Yuri B.
# Clarson G.
# Lorena C.
# Mariana P.
# Mariana M.
# Caio T.
# Daniela O.
# Lucas V.
# Mauro J.
# Tafarel c.
# Bruna Regina B.
# Rafael A.
# Lorena M.
# Johnatan G.
# Fernando L.
# João Paulo H.
# Hugo O.
# Silvio C.
# Isaias G.
# LUCAS MARIANO P.
# Mariana A.
# Jordi R.
# Laisa S.
# Paulo C.
# Laercio L.
# Hyan F.
# Paulo Afonso  B.
# Fernanda Z.
# Bruno C.
# Warlley Gonçalves d.
# Arthur M.
# Yago B.
# Marcello N.
# Marilia M.
# Marcos C.
# Letícia R.
# Isabela B.
# Raphael G.
# Clóvis N.
# Lucas G.
# Thays L.
# Rivana B.
# Tiago A.
# João Victor M.
# Victor Hugo O.
# Amanda L.
# Augusto G.
#
# Descriptive Terms: software
# ------------------------------------------------------------
# Wagner S.
# Rafael F.
# Vinícius C.
# Eduardo M.
# Fábio F.
# Yuri B.
# Jeias S.
# Vinícius R.
# Maressa S.
#
# Descriptive Terms: Lí
# ------------------------------
# Wesley P.
# Lorena B.
# Gustavo F.
# Felipe P.
# Diego V.
# Thiego R.
# Lorena L.
# Lilian D.
# Lorena M.
#
# Descriptive Terms:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Lourenço R.
# Lourenço R.
# Augusto N.
# Ayres B.
# Guilherme S.
# Rafael F.
# Vinicius d.
# Willie O.
# Eduardo M.
# Arthur C.
# Túlio M.
# Bruno C.
# Denilson S.
# Vandré L.
# Renato R.
# Ricardo B.
# Ricardo B.
# Ricardo B.
# Ricardo B.
# Alan F.
# Leonardo P.
# William Johnson d.
# Artur C.
# Eduardo J.
# Moreno Z.
# Danniel F.
# Danniel F.
# Silvestre S.
# Pedro  E.
# Larissa A.
# Nivaldo J.
# Paulo Henrique M.
# Samuel H.
# Hiago A.
# Willian A.
# Thiago C.
# Ítalo Louis A.
# Adriano L.
# Paula B.
# Lucas T.
# Ricardo D.
# Arthur Cesar D.
# Rafael F.
# João Vitor A.
# Igor A.
# Flávio A.
# Renato M.
# Guilherme D.
# Rafael Z.
# Sérgio P.
# Victor d.
# Luan  D.
# Felipe Amâncio D.
# Wayner M.
# Thiago A.
# Matheus J.
# Matheus J.
# José J.
# Henrique M.
# Tiago S.
# Vinícius R.
# Lucas M.
# João Augusto M.
# Maressa S.
#
# Descriptive Terms: Data
# -------------------------------------------------------------------------------
# Márcio Heleno d.
# Henrique C.
# Henrique C.
# Lucas B.
# Lucas B.
#
# Descriptive Terms: Watson
# ------------------------------------------
# Roberto C.
# Roberto C.
#
# Descriptive Terms:
# ------------------------------------------------------------------------------------------------------
# Eduardo M.
# Elediane Micheli B.
# Luzidalva L.
# Luzidalva L.
# Rodrigo B.
#
# Descriptive Terms:
# ---------------------------------------------
# Bruno M.
# Edgar Zattar D.
# Cristiano O.
# Sthéfani R.
# Rita M.
#
# Descriptive Terms: Analista
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Rodolfo M.
# Thiago Willian A.
# Renato Dalmo L.
# Rodrigo F.
# Paulo V.
# Nathália R.
# Edilene C.
# Fabiano D.
# Mônica d.
# Jerry G.
# Fernanda B.
# Jakeline B.
# Kele M.
# Warla  L.
# Danilo N.
# Lucas R.
# Thais R.
# Diego H.
# Tarcisio M.
# Rafael B.
# Arlindo J.
# Matheus F.
# Gabriel E.
# Luiz F.
# Laura M.
# Matheus L.
# Arthur D.
# Vagner A.
# Vitor Soares C.
# Andreia V.
# Clayton M.
# Clayton M.
# Hellen C.
# Humberto C.
# Juliana F.
# Rondinele S.
# Diego M.
# Isaac R.
# Marvin  B.
# Bruno Q.
# Matheus D.
# Vander G.
# Layson D.
# Vítor B.
# Juliana V.
# Claudia E.
# Alex D.
# João T.
# João Paulo M.
# Nina Bárbara d.
# Melissa M.
# Marcos M.
# Jerveson L.
# Juliana B.
# Roger S.
# Samuel R.
# Roberto R.
# Analice S.
# João M.
# Nayara M.
# Rafael R.
# Thiago R.
# Marianna C.
# Yuri B.
# Clarson G.
# Lorena C.
# Mariana P.
# Mariana M.
# Caio T.
# Daniela O.
# Lucas V.
# Mauro J.
# Tafarel c.
# Bruna Regina B.
# Rafael A.
# Lorena M.
# Johnatan G.
# Fernando L.
# Hugo O.
# Silvio C.
# Isaias G.
# LUCAS MARIANO P.
# Mariana A.
# Jordi R.
# Laisa S.
# Laercio L.
# Hyan F.
# Paulo Afonso  B.
# Fernanda Z.
# Bruno C.
# Warlley Gonçalves d.
# Arthur M.
# Yago B.
# Marcello N.
# Marilia M.
# Marcos C.
# Letícia R.
# Isabela B.
# Raphael G.
# Clóvis N.
# Thays L.
# Tiago A.
# João Victor M.
# Victor Hugo O.
# Amanda L.
# Augusto G.
#
# Descriptive Terms:
# -------------------------------------------------------------------------------
# Rogger F.
# Vítor B.
# João Paulo M.
# Johnatan G.
# Paulo Afonso  B.
# Augusto G.
#
# Descriptive Terms:
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Rodrigo M.
# Bruno Garcia d.
# Gabriella J.
# Luzidalva L.
# Kyros Tecnologia - R.
# Elisangela F.
# Mariana D.
# Nayane R.
# Marco S.
# Fabio P.
# Mariá M.
# Marilia M.
#
# Descriptive Terms:
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Lourenço R.
# Lourenço R.
# Augusto N.
# Ayres B.
# Guilherme S.
# Rafael F.
# Vinicius d.
# Willie O.
# Eduardo M.
# Arthur C.
# Túlio M.
# Bruno C.
# Denilson S.
# Vandré L.
# Renato R.
# Ricardo B.
# Ricardo B.
# Ricardo B.
# Ricardo B.
# Ricardo B.
# Alan F.
# Leonardo P.
# William Johnson d.
# Artur C.
# Eduardo J.
# Moreno Z.
# Danniel F.
# Danniel F.
# Silvestre S.
# Pedro  E.
# Larissa A.
# Nivaldo J.
# Paulo Henrique M.
# Samuel H.
# Hiago A.
# Willian A.
# Thiago C.
# Ítalo Louis A.
# Adriano L.
# Paula B.
# Lucas T.
# Ricardo D.
# Arthur Cesar D.
# Rafael F.
# João Vitor A.
# Igor A.
# Flávio A.
# Renato M.
# Guilherme D.
# Sérgio P.
# Luan  D.
# Felipe Amâncio D.
# Wayner M.
# Thiago A.
# Matheus J.
# Matheus J.
# José J.
# Henrique M.
# Tiago S.
# Vinícius R.
# Lucas M.
# João Augusto M.
# Maressa S.
#
# Descriptive Terms: Engenheiro
# ----------------------------------------------------------------------------
# Weverton L.
# Felipe A.
# Eurípedes C.
# Thayron S.
# Jeias S.
#
# Descriptive Terms: Gerente
# -------------------------------------------------------------------------------------------
# Sergio S.
# Bruno M.
# Mateus L.
# Rodrigo C.
# Robson P.
# Arthur F.
# Edgar Zattar D.
# Cristiano O.
# Renato R.
# Flávia M.
# Renato M.
# Henrique C.
# Maria Rita M.
# Juliana M.
# Gregonio E.
# Gabriel P.
# Fernando S.
# Kriscia M.
# Caio C.
# Lilian S.
# Mariá M.
# Rita M.
# Davi G.
# Davi G.
# Anderson L.
#
# Descriptive Terms: senvolvimento
# ---------------------------------------------------
# Lucas R.
# Matheus F.
# Isaac R.
# Layson D.
# Marcos Rodrigo S.
# Caio T.
# Meline M.
#
# Descriptive Terms: Java
# ----------------------------------------------------
# Layson D.
# Marco Túlio A.
#
# Descriptive Terms: Qualida
# -----------------------------------------------
# Clayton M.
# Clayton M.
# Claudia E.
# Nayara M.
#
# Descriptive Terms: Coordenador
# ----------------------------------------------------
# Fábio C.
# Clayton M.
#
# Descriptive Terms: Engenheiro, de
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Lourenço R.
# Lourenço R.
# Augusto N.
# Ayres B.
# Guilherme S.
# Rafael F.
# Vinicius d.
# Willie O.
# Eduardo M.
# Arthur C.
# Túlio M.
# Bruno C.
# Denilson S.
# Vandré L.
# Renato R.
# Ricardo B.
# Ricardo B.
# Ricardo B.
# Alan F.
# Leonardo P.
# William Johnson d.
# Artur C.
# Eduardo J.
# Moreno Z.
# Danniel F.
# Danniel F.
# Silvestre S.
# Pedro  E.
# Larissa A.
# Nivaldo J.
# Paulo Henrique M.
# Samuel H.
# Hiago A.
# Willian A.
# Thiago C.
# Ítalo Louis A.
# Adriano L.
# Paula B.
# Lucas T.
# Ricardo D.
# Arthur Cesar D.
# Rafael F.
# João Vitor A.
# Igor A.
# Flávio A.
# Renato M.
# Guilherme D.
# Sérgio P.
# Luan  D.
# Felipe Amâncio D.
# Wayner M.
# Thiago A.
# Matheus J.
# Matheus J.
# José J.
# Henrique M.
# Tiago S.
# Vinícius R.
# Lucas M.
# João Augusto M.
# Maressa S.
#
# Descriptive Terms: Programmer
# -----------------------------------------
# Pablo W.
# Lucas G.
# Fernando B.
# Raissa O.
#
# Descriptive Terms: Specialist
# --------------------------------------------------------------------
# Thiago Henrique C.
# Lucas R.
# Ricardo P.
# Carlos Eduardo G.
# Wannisson F.
# Renan D.
#
# Descriptive Terms: vendas
# --------------------------------------------------------------
# LUIS L.
# Alex Sandro B.
# Giovanna A.
# Alexandre G.
# Anderson L.
#
# Descriptive Terms: End
# --------------------------------------------------
# Douglas F.
# Dione Munir S.
# Bruno C.
# Cristiano L.
# Flávio A.
# José Lemes N.
#
# Descriptive Terms: negócios
# --------------------------------------------------------------------
# Nathália R.
# Edilene C.
# Daniel R.
# Elisangela F.
# Marcos Rodrigo S.
# Marcello N.
#
# Descriptive Terms: Engenheiro, de
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Lourenço R.
# Lourenço R.
# Ayres B.
# Guilherme S.
# Rafael F.
# Vinicius d.
# Willie O.
# Eduardo M.
# Arthur C.
# Túlio M.
# Bruno C.
# Denilson S.
# Vandré L.
# Renato R.
# Ricardo B.
# Ricardo B.
# Ricardo B.
# Alan F.
# Leonardo P.
# William Johnson d.
# Artur C.
# Eduardo J.
# Moreno Z.
# Danniel F.
# Danniel F.
# Silvestre S.
# Pedro  E.
# Larissa A.
# Nivaldo J.
# Paulo Henrique M.
# Samuel H.
# Hiago A.
# Willian A.
# Thiago C.
# Ítalo Louis A.
# Adriano L.
# Paula B.
# Lucas T.
# Ricardo D.
# Arthur Cesar D.
# Rafael F.
# João Vitor A.
# Igor A.
# Flávio A.
# Guilherme D.
# Sérgio P.
# Luan  D.
# Felipe Amâncio D.
# Wayner M.
# Thiago A.
# Matheus J.
# Matheus J.
# José J.
# Henrique M.
# Tiago S.
# Vinícius R.
# Lucas M.
# João Augusto M.
# Maressa S.
#
# Descriptive Terms: Developer
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Lucas S.
# Henrique P.
# Henrique P.
# Rita de Cássia C.
# Samuel F.
# LIGIA S.
# Lucas Arruda V.
# Dione Munir S.
# Nilson B.
# Ramiro S.
# Gustavo G.
# Diego Ricardo c.
# Vinicius A.
# Pedro G.
# Dario Soares N.
# Marco Túlio A.
# Victor d.
# Augusto P.
# Guilherme C.
# Helton J.
# Bruno R.
# Paulo Cesar C.
# José Lemes N.
# Mateus Henrique A.
# Rafael C.
# Bruno C.
#
# Descriptive Terms:
# -------------------------------------------------------------------------------------------------
# Thiago Caetano C.
# Thiago Caetano C.
# Eder B.
# Eder B.
# Eder B.
# Eder B.
# Francisco C.
# Wesley P.
# Henrique P.
# Henrique P.
# Rita de Cássia C.
# Ricardo P.
# José Pedro D.
# Frederico A.
# LIGIA S.
# Priscila G.
# Lorena B.
# Nilson B.
# Luismar C.
# Gustavo F.
# Pablo P.
# Felipe P.
# Diego V.
# Gustavo G.
# Gustavo G.
# Paulo Rogério L.
# Thiego R.
# Tiago R.
# Marcos M.
# Filipe F.
# Filipe F.
# Lorena L.
# Lilian D.
# IT2YOU P.
# Guilherme C.
# 💳 Susy Nunes O.
# Lorena M.
# Amanda L.
#
# Descriptive Terms:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Rodolfo M.
# Rodrigo F.
# Paulo V.
# Danilo N.
# Leonardo P.
# Daniel S.
# Humberto C.
# Diego M.
# Vítor B.
# Alex D.
# Roberto R.
# Clarson G.
# Hugo O.
# Silvio C.
# Laercio L.
# Paulo Afonso  B.
# Alessandro A.
#
# Descriptive Terms: PMO
# ------------------------------------
# Daniel A.
# Lucas A.
#
# Descriptive Terms: Business
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Jorge Eurípedes d.
# Bruno Garcia d.
# Marcelo S.
# Lucas Arruda V.
# Warla  L.
# Alexandre R.
# Brenner M.
# Hugo A.
# Stephanny A.
# Marco Tulio B.
# Victor S.
# Rafaela d.
# Dario Soares N.
# Samuel R.
# Analice S.
# Thiago A.
# Ariel Leon L.
# Helton J.
#
# Descriptive Terms: Consultor
# --------------------------------------------------------------------------------------------------
# Eric R.
# Rodrigo M.
# Renato R.
# Luis J.
# Lucas A.
# Carlos F.
# LUIS L.
# Giovanna A.
# Alexandre G.
#
# Descriptive Terms:
# --------------------------------------------------------------------------------------------------
# Daniel R.
# Fernando C.
# Renato R.
# Brenner M.
# Ramiro S.
# Weverton L.
# Ruth C.
#
# Descriptive Terms: Professor
# ---------------------------------------------------------------------------------------------
# Marcelo R.
# Daniel Duarte A.
# Daniel M.
# Vitor C.
# Saulo J.
# Igor M.
#
# Descriptive Terms: Programador
# ----------------------------------------------------------------
# Giliard J.
# Moreno Z.
# Patrick O.
# Nivaldo P.
# Romario V.
# Tales R.
# Daniel V.
#
# Descriptive Terms:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Lourenço R.
# Lourenço R.
# Ayres B.
# Guilherme S.
# Rafael F.
# Vinicius d.
# Willie O.
# Eduardo M.
# Arthur C.
# Túlio M.
# Bruno C.
# Denilson S.
# Vandré L.
# Renato R.
# Renato R.
# Ricardo B.
# Ricardo B.
# Ricardo B.
# Alan F.
# Leonardo P.
# William Johnson d.
# Artur C.
# Eduardo J.
# Moreno Z.
# Danniel F.
# Danniel F.
# Weverton L.
# Weverton L.
# Silvestre S.
# Pedro  E.
# Larissa A.
# Nivaldo J.
# Paulo Henrique M.
# Samuel H.
# Hiago A.
# Willian A.
# Ítalo Louis A.
# Adriano L.
# Paula B.
# Lucas T.
# Ricardo D.
# Arthur Cesar D.
# Felipe A.
# Rafael F.
# João Vitor A.
# Igor A.
# Flávio A.
# Guilherme D.
# Sérgio P.
# Luan  D.
# Felipe Amâncio D.
# Wayner M.
# Thiago A.
# Jeias S.
# Matheus J.
# Matheus J.
# José J.
# Ruth C.
# Henrique M.
# Tiago S.
# Vinícius R.
# Lucas M.
# João Augusto M.
# Maressa S.
#
# Descriptive Terms:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Moniele S.
# Brenner M.
# Marcio G.
# Ramiro S.
# Stephanny A.
# Marco Tulio B.
# Breno S.
# Lucas B.
# Lucas B.
# Anderson A.
# Matheus S.
#
# Descriptive Terms:
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------
# Júlio César S.
# Cristiano L.
# Arthur M.
# Moreno Z.
# Patrick O.
# Nivaldo P.
# Romario V.
# Tales R.
# Marcos C.
# Alessandro A.
# Vinícius R.
# Daniel V.
# Pedro H.
#
# Descriptive Terms: Engenheiro, de
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Lourenço R.
# Lourenço R.
# Guilherme S.
# Túlio M.
# Vandré L.
# Ricardo B.
# Ricardo B.
# Alan F.
# Danniel F.
# Pedro  E.
# Larissa A.
# Paulo Henrique M.
# Ítalo Louis A.
# Paula B.
# Lucas T.
# João Vitor A.
# Flávio A.
# Luan  D.
# Felipe Amâncio D.
# Wayner M.
# Matheus J.
# Henrique M.
# Lucas M.
# João Augusto M.
# Maressa S.
#
# Descriptive Terms: Database
# --------------------------------------------------
# Francisco C.
# Francisco C.
# Leonardo L.
#
# Descriptive Terms: Business
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Jorge Eurípedes d.
# Bruno Garcia d.
# Marcelo S.
# Lucas Arruda V.
# Warla  L.
# Alexandre R.
# Brenner M.
# Hugo A.
# Marco Tulio B.
# Dario Soares N.
# Helton J.
#
# Descriptive Terms: Programador
# ----------------------------------------------------------------------------------------------------------------------------------------------
# Júlio César S.
# Cristiano L.
# Arthur M.
# Hugo A.
# Moreno Z.
# Patrick O.
# Nivaldo P.
# Romario V.
# Tales R.
# Alessandro A.
# Daniel V.
#
# Descriptive Terms: Senior, Analyst
# --------------------------------------------------------------------------------------
# Weder C.
# Alessandra S.
#
# Descriptive Terms: Consultant
# -----------------------------------------------
# Carlos Eduardo Alves S.
# Erik M.
#
# Descriptive Terms: Desenvolvimento
# --------------------------------------------------------------
# Rodrigo C.
# Bruno Q.
# Arthur M.
#
# Descriptive Terms: Engenheiro, de
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Lourenço R.
# Lourenço R.
# Guilherme S.
# Túlio M.
# Vandré L.
# Ricardo B.
# Ricardo B.
# Alan F.
# Danniel F.
# Pedro  E.
# Larissa A.
# Paulo Henrique M.
# Ítalo Louis A.
# Paula B.
# Lucas T.
# João Vitor A.
# Luan  D.
# Felipe Amâncio D.
# Wayner M.
# Matheus J.
# Henrique M.
# Lucas M.
# João Augusto M.
# Maressa S.
#
# Descriptive Terms:
# ---------------------------------------------------------------------------------------------------------------------
# Thiago Henrique C.
# Rogerio T.
# Rogerio T.
# Ricardo R.
# Carlos M.
# Breno S.
# Elner R.
#
# Descriptive Terms: Pleno
# ---------------------------------------------------------
# Vítor B.
# João Paulo M.
# Johnatan G.
# Paulo Afonso  B.
#
# Descriptive Terms: Arquiteto
# -----------------------------------------------
# Wagner S.
# Vinícius C.
# Fábio F.
# Hellen C.
# Adauto A.
# Lucas P.
#
# Descriptive Terms:
# -----------------------------------------------------------------------------------------------------------------
# Bruno M.
# Lucas R.
# Ricardo P.
# Carlos Eduardo Alves S.
# Rodrigo M.
# Carlos Eduardo G.
# Wannisson F.
# Isaias G.
# Renan D.
#
# Descriptive Terms: System
# ------------------------------------------------
# Thiago Henrique C.
# Breno S.
#
# Descriptive Terms: Lea
# ---------------------------------------------------------------------------------
# Rogerio T.
# Francisco C.
# Henrique P.
# Rita de Cássia C.
# Ricardo P.
# Frederico A.
# LIGIA S.
# Priscila G.
# Nilson B.
# Lilian Christina O.
# Gustavo G.
# Guilherme C.
#
# Descriptive Terms: Júnior
# -------------------------------------------------------------
# Clarson G.
# Alessandro A.
#
# Descriptive Terms:
# --------------------------------------------------------------------------------------------------------------
# Hellen C.
# Marcos M.
# Roberto R.
# Mariana A.
# Hyan F.
# Thais C.
# Victor Hugo O.
# Amanda L.
#
# Descriptive Terms:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Henrique P.
# Henrique P.
# Rita de Cássia C.
# Samuel F.
# LIGIA S.
# Dione Munir S.
# Ricardo B.
# Nilson B.
# Ramiro S.
# Danniel F.
# Danniel F.
# Diego Ricardo c.
# Thiago C.
# Pedro G.
# Marco Túlio A.
# Augusto P.
# Guilherme C.
# Paulo Cesar C.
# José Lemes N.
# Mateus Henrique A.
# Matheus J.
# Matheus J.
# Rafael C.
# Bruno C.
#
# Descriptive Terms: Lea
# ----------------------------------------------------------------------------------------------------------------------------------------------------------
# Thiago Caetano C.
# Rogerio T.
# Francisco C.
# Henrique P.
# Ricardo P.
# José Pedro D.
# Frederico A.
# Priscila G.
# Nilson B.
# Luismar C.
# Pablo P.
# Lilian Christina O.
# Gustavo G.
# Guilherme C.
#
# Descriptive Terms:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------
# Jorge Eurípedes d.
# Marcelo S.
# Brenner M.
# Ramiro S.
# Stephanny A.
# Marco Tulio B.
# Marco Tulio B.
# Breno S.
# Matheus S.
# Lucas R.
#
# Descriptive Terms:
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Rodrigo M.
# Edilene C.
# Bruno Garcia d.
# Luzidalva L.
# Elisangela F.
# Marco S.
# Thiago R.
#
# Descriptive Terms:
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Thiago Caetano C.
# Rodolfo M.
# Thiago Willian A.
# Renato Dalmo L.
# Rodrigo F.
# Paulo V.
# Nathália R.
# Edilene C.
# Fabiano D.
# Mônica d.
# Jerry G.
# Elediane Micheli B.
# Fernanda B.
# Eric R.
# Jakeline B.
# Kele M.
# Warla  L.
# Henrique C.
# Danilo N.
# Lucas R.
# Thais R.
# Diego H.
# Tarcisio M.
# Rafael B.
# Rafael B.
# Arlindo J.
# Matheus F.
# Gabriel E.
# Luiz F.
# Laura M.
# Matheus L.
# Arthur D.
# Vagner A.
# Vitor Soares C.
# Andreia V.
# Clayton M.
# Clayton M.
# Hellen C.
# Humberto C.
# Juliana F.
# Rondinele S.
# Diego M.
# Isaac R.
# Marvin  B.
# Bruno Q.
# Matheus D.
# Vander G.
# Layson D.
# Vítor B.
# Carlos F.
# Juliana V.
# Claudia E.
# Alex D.
# João T.
# João Paulo M.
# Nina Bárbara d.
# Melissa M.
# Marcos M.
# Jerveson L.
# Juliana B.
# Roger S.
# Samuel R.
# Roberto R.
# Analice S.
# João M.
# Nayara M.
# Rafael R.
# Thiago R.
# Marianna C.
# Yuri B.
# Clarson G.
# Lorena C.
# Mariana P.
# Mariana M.
# Caio T.
# Daniela O.
# Lucas V.
# Mauro J.
# Tafarel c.
# Bruna Regina B.
# Rafael A.
# Lorena M.
# Johnatan G.
# Johnatan G.
# Fernando L.
# Hugo O.
# Silvio C.
# Isaias G.
# LUCAS MARIANO P.
# Mariana A.
# Jordi R.
# Laisa S.
# Laercio L.
# Hyan F.
# Paulo Afonso  B.
# Fernanda Z.
# Bruno C.
# Warlley Gonçalves d.
# Arthur M.
# Yago B.
# Marcello N.
# Marilia M.
# Marcos C.
# Letícia R.
# Isabela B.
# Raphael G.
# Clóvis N.
# Thays L.
# Tiago A.
# João Victor M.
# Victor Hugo O.
# Amanda L.
# Augusto G.
#
# Descriptive Terms: Developer
# ----------------------------------------------------------------------------------------------------------------------------------------------
# Henrique P.
# Henrique P.
# Rita de Cássia C.
# Samuel F.
# LIGIA S.
# Dione Munir S.
# Nilson B.
# Ramiro S.
# Diego Ricardo c.
# Pedro G.
# Marco Túlio A.
# Augusto P.
# Guilherme C.
# Paulo Cesar C.
# José Lemes N.
# Rafael C.
#
# Descriptive Terms: Master, Scrum
# ------------------------------------------------------------------------------------------------
# Robson P.
# Jerry G.
# Gil Victor Teixeira P.
#
# Descriptive Terms: Supervisor
# --------------------------------------------------------------
# Rafael R.
# Djone machado M.
# Rafael B.
# Fabio P.
#
# Descriptive Terms: QA
# ---------------------------------------------------
# Marvin  B.
# Isaias G.
# Paulo Anderson B.
#
# Descriptive Terms: Lea
# ------------------------------------------------------------------------------------------------------
# Rogerio T.
# Francisco C.
# Henrique P.
# Ricardo P.
# Frederico A.
# Priscila G.
# Gustavo G.
# Gustavo G.
# Guilherme C.
#
# Descriptive Terms: Operações
# -----------------------------------------------------------------------------------------------------------
# Edgar Zattar D.
# Henrique C.
# Maria Rita M.
# Juliana M.
# Davi C.
# Rodrigo A.
# Davi G.
# Davi G.
#
# Descriptive Terms: Versão
# -----------------------------------------------
# Clayton M.
# Clayton M.
#
# Descriptive Terms:
# ----------------------------------------------------------------------
# Mônica d.
# Fernanda P.
# Laís M.
# Lara L.
# Juliana M.
# Andreia V.
# Juliana F.
# Kriscia M.
# Juliana V.
# Melissa M.
# Juliana B.
# Késsen Santos de  P.
# Lorena C.
# Mariana M.
#
# Descriptive Terms:
# ----------------------------------------------------------------------------------------------
# Rodolfo M.
# Rodrigo F.
# Paulo V.
# Danilo N.
# Hellen C.
# Humberto C.
# Diego M.
# Vítor B.
# Alex D.
# Roberto R.
# Hugo O.
# Silvio C.
# Laercio L.
# Paulo Afonso  B.
# Thais C.
#
# Descriptive Terms: Analista
# --------------------------------------------------------
# Rodolfo M.
# Renato Dalmo L.
# Rodrigo F.
# Paulo V.
# Nathália R.
# Edilene C.
# Fabiano D.
# Mônica d.
# Fernanda B.
# Kele M.
# Warla  L.
# Danilo N.
# Lucas R.
# Thais R.
# Diego H.
# Tarcisio M.
# Rafael B.
# Arlindo J.
# Matheus F.
# Gabriel E.
# Luiz F.
# Laura M.
# Matheus L.
# Arthur D.
# Vitor Soares C.
# Andreia V.
# Clayton M.
# Clayton M.
# Humberto C.
# Juliana F.
# Rondinele S.
# Diego M.
# Isaac R.
# Marvin  B.
# Bruno Q.
# Matheus D.
# Vander G.
# Layson D.
# Vítor B.
# Juliana V.
# Claudia E.
# Alex D.
# João T.
# João Paulo M.
# Nina Bárbara d.
# Melissa M.
# Marcos M.
# Juliana B.
# Samuel R.
# Roberto R.
# Analice S.
# João M.
# Nayara M.
# Rafael R.
# Thiago R.
# Marianna C.
# Yuri B.
# Clarson G.
# Lorena C.
# Mariana P.
# Mariana M.
# Caio T.
# Daniela O.
# Lucas V.
# Mauro J.
# Tafarel c.
# Tafarel c.
# Bruna Regina B.
# Rafael A.
# Lorena M.
# Johnatan G.
# Fernando L.
# Hugo O.
# Silvio C.
# Isaias G.
# LUCAS MARIANO P.
# Mariana A.
# Jordi R.
# Laisa S.
# Laercio L.
# Hyan F.
# Paulo Afonso  B.
# Fernanda Z.
# Bruno C.
# Warlley Gonçalves d.
# Arthur M.
# Yago B.
# Marcello N.
# Marilia M.
# Letícia R.
# Isabela B.
# Raphael G.
# Clóvis N.
# Thays L.
# Tiago A.
# João Victor M.
# Victor Hugo O.
# Amanda L.
# Augusto G.
#
# Descriptive Terms: Analista, Custo, e
# ----------------------------------------------------------------------------
#  Crênio Roberto S.
#  Crênio Roberto S.
#
# Descriptive Terms: Vendas
# ------------------------------------------
# Roberto C.
# Roberto C.
# Fabio Luis S.
# Renato M.
#  Hingrid Therèse R.
#
# Descriptive Terms: Projetos
# -------------------------------------------------------------------
# Gregonio E.
# Thiego R.
# Caio C.
# Fernanda B.
# Lorena L.
# Davi G.
# Davi G.
#
# Descriptive Terms: testes
# ------------------------------------------
# Wesley P.
# Kele M.
# Sergio dos Santos M.
# Carlos Alberto Jr  , M.
# Matheus D.
# Clóvis N.
#
# Descriptive Terms: humanos
# ----------------------------------------------------
# Fernanda P.
# Meline M.
# Fernanda Z.
# Isabela B.
#
# Descriptive Terms:
# -------------------------------------------------------------------------------------------------------------------------------------
# Marcos Antonio O.
# Guilherme S.
# Mauricio D.
# Flavia B.
# Daniel S.
# Renan S.
# Daniel T.
# Hiago P.
# Vitor Bruno L.
# José I.
# Thiago A.
# Mauro J.
# Mauro J.
# Kayke M.
# Rodrigo G.
#
# Descriptive Terms: Intelligence, Business
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Jorge Eurípedes d.
# Bruno Garcia d.
# Marcelo S.
# Lucas Arruda V.
# Alexandre R.
# Brenner M.
# Hugo A.
# Dario Soares N.
# Helton J.
#
# Descriptive Terms: em, Especialista
# -----------------------------------------------------------------------------------------------
# Bruno Garcia d.
# Marco S.
#
# Descriptive Terms: Analytics
# ------------------------------------------------------------------------
# Mateus L.
# Henrique C.
# Henrique C.
# Joeudes A.
# Lucas B.
# Lucas B.
# Arthur P.'. de G.
#
# Descriptive Terms: projetos
# -------------------------------------------------
# Arthur F.
# Flávia M.
# Lorena B.
# Lilian S.
#
# Descriptive Terms:
# -------------------------------------------------------------------------------------------------------
# Rodrigo A.
# Mayara M.
# João Paulo H.
# Lucas G.
# Rivana B.
# Wagner S.
#
# Descriptive Terms: Professor
# --------------------------------------------------------------------------
# Marcelo R.
# Vitor C.
# Saulo J.
# Igor M.
#
# Descriptive Terms: Chief, Officer
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Eder B.
# Eder B.
# Eder B.
# Maria Emília D.
# Diego D.
# Alexandre Augusto A.
# Rafael M.
# Fernando S.
# Fernando S.
#
# Descriptive Terms: Desenvolvimento
# -----------------------------------------------------------------------------------------
# Arthur D.
# Arthur D.
# Bruno Q.
# Arthur M.
#
# Descriptive Terms: r
# ---------------------------------------------------------------------
# Thiago Caetano C.
# Thiago Caetano C.
# Eder B.
# Eder B.
# Eder B.
# Eder B.
# Francisco C.
# Wesley P.
# Henrique P.
# Henrique P.
# Rita de Cássia C.
# Ricardo P.
# José Pedro D.
# Frederico A.
# LIGIA S.
# Priscila G.
# Lorena B.
# Nilson B.
# Luismar C.
# Gustavo F.
# Pablo P.
# Diego V.
# Gustavo G.
# Gustavo G.
# Paulo Rogério L.
# Thiego R.
# Tiago R.
# Filipe F.
# Filipe F.
# Lorena L.
# Lilian D.
# IT2YOU P.
# Guilherme C.
# 💳 Susy Nunes O.
# Lorena M.
#
# Descriptive Terms: Developer
# --------------------------------------------------------------------------------------------------------------------------
# Gustavo G.
# Diego Ricardo c.
# Bruno R.
# Bruno R.
# Rafael C.
#
# Descriptive Terms: equipe
# --------------------------------------------
# Gustavo F.
# Diego V.
# Lorena M.
#
# Descriptive Terms: Especialista
# -----------------------------------------------
# Elediane Micheli B.
# Luzidalva L.
#
# Descriptive Terms: nadora
# ----------------------------------------
# Laís M.
# Lara L.
# Fernanda F.
# Camila T.
# Fernanda B.
# Monique B.
#  Hingrid Therèse R.
#
# Descriptive Terms: Analyst
# ---------------------------------------------
# Brenner M.
# Ramiro S.
# Paulo Anderson B.
#
# Descriptive Terms: r
# --------------------------------------------------------
# Thiago Caetano C.
# Thiago Caetano C.
# Eder B.
# Eder B.
# Eder B.
# Eder B.
# Francisco C.
# Wesley P.
# Henrique P.
# Henrique P.
# Rita de Cássia C.
# Ricardo P.
# José Pedro D.
# Frederico A.
# LIGIA S.
# Priscila G.
# Lorena B.
# Nilson B.
# Luismar C.
# Gustavo F.
# Pablo P.
# Diego V.
# Gustavo G.
# Gustavo G.
# Paulo Rogério L.
# Thiego R.
# Filipe F.
# Filipe F.
# Lorena L.
# Lilian D.
# IT2YOU P.
# Guilherme C.
# 💳 Susy Nunes O.
# Lorena M.
#
# Descriptive Terms: Developer
# ---------------------------------------------------------------------------------------------------------------------------
# Henrique P.
# Henrique P.
# Rita de Cássia C.
# Samuel F.
# LIGIA S.
# Dione Munir S.
# Nilson B.
# Diego Ricardo c.
# Pedro G.
# Marco Túlio A.
# Augusto P.
# Guilherme C.
# José Lemes N.
# Rafael C.
#
# Descriptive Terms: Lea, Operations, Wholesales
# -----------------------------------------------------------------------------
# Thiago Caetano C.
# Thiago Caetano C.
#
# Descriptive Terms: Senior
# --------------------------------------------------------------------------------
# Bruno M.
# Carlos Eduardo Alves S.
# Rodrigo M.
# Isaias G.
#
# Descriptive Terms: Lea
# -------------------------------------------------
# Rogerio T.
# Francisco C.
# Henrique P.
# Ricardo P.
# Frederico A.
# Priscila G.
# Guilherme C.
#
# Descriptive Terms: Talentos, Humanos
# -------------------------------------------------------------------------------
# Mônica d.
# Vanderlei G.
# Juliana M.
# Kriscia M.
# Melissa M.
# Raphael G.
#
# Descriptive Terms: Lea
# -------------------------------------------------------------------------
# Rogerio T.
# Francisco C.
# Henrique P.
# Henrique P.
# Ricardo P.
# José Pedro D.
# Priscila G.
# Guilherme C.
#
# Descriptive Terms: Technical, Lead
# --------------------------------------------------------------
# Lourenço R.
# Lourenço R.
#
# Descriptive Terms: Foun
# -------------------------------
# Eder B.
# Eder B.
# Paulo Rogério L.
# Filipe F.
# IT2YOU P.
# 💳 Susy Nunes O.
#
# Descriptive Terms:
# ----------------------------------------------------------------------------------------------------------------------------
# Henrique P.
# Henrique P.
# Rita de Cássia C.
# Samuel F.
# Júlio César S.
# LIGIA S.
# Dione Munir S.
# Nilson B.
# Diego Ricardo c.
# Pedro G.
# Augusto P.
# Guilherme C.
# José Lemes N.
# Rafael C.
#
# Descriptive Terms: Center, Lea
# ---------------------------------------------------
# Henrique P.
# José Pedro D.
#
# Descriptive Terms: Produto
# ---------------------------------------------
# Alan Á.
# Pedro C.
#
# Descriptive Terms: Developer
# --------------------------------------------------------------------------------------------
# Henrique P.
# Henrique P.
# Rita de Cássia C.
# Samuel F.
# LIGIA S.
# Dione Munir S.
# Nilson B.
# Diego Ricardo c.
# Pedro G.
# Guilherme C.
# José Lemes N.
# Rafael C.
#
# Descriptive Terms: Developer
# --------------------------------------------------------------------------------------------------------
# Henrique P.
# Henrique P.
# Rita de Cássia C.
# LIGIA S.
# Dione Munir S.
# Nilson B.
# Diego Ricardo c.
# Pedro G.
# Guilherme C.
# Bruno R.
# José Lemes N.
# Rafael C.
#
# Descriptive Terms: Team
# ---------------------------------------
# Rogerio T.
# Francisco C.
# Francisco C.
# Priscila G.
#
# Descriptive Terms: Sênior
# ----------------------------------------------------------------------
# Graziele P.
# Rondinele S.
# Isadora R.
#
# Descriptive Terms: Engenheiro, de
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Lourenço R.
# Lourenço R.
# Guilherme S.
# Túlio M.
# Vandré L.
# Ricardo B.
# Ricardo B.
# Alan F.
# Danniel F.
# Pedro  E.
# Larissa A.
# Paulo Henrique M.
# Ítalo Louis A.
# Paula B.
# Lucas T.
# Luan  D.
# Felipe Amâncio D.
# Wayner M.
# Matheus J.
# Henrique M.
# Lucas M.
# João Augusto M.
# Maressa S.
#
# Descriptive Terms: Lea, Team
# ---------------------------------------------------------
# Rogerio T.
# Rogerio T.
# Francisco C.
# Priscila G.
#
# Descriptive Terms: BI
# ---------------------------------------------------------------------------------------------
# Thiago Caetano C.
# Thiago Willian A.
# Elediane Micheli B.
# Eric R.
# Henrique C.
# Rafael B.
# Carlos F.
# Carlos F.
# Johnatan G.
#
# Descriptive Terms: Analista
# --------------------------------------------------------------------------------------------------------------------------
# Rodolfo M.
# Renato Dalmo L.
# Rodrigo F.
# Paulo V.
# Nathália R.
# Edilene C.
# Fabiano D.
# Mônica d.
# Jerry G.
# Fernanda B.
# Jakeline B.
# Kele M.
# Warla  L.
# Danilo N.
# Lucas R.
# Thais R.
# Diego H.
# Tarcisio M.
# Rafael B.
# Arlindo J.
# Matheus F.
# Gabriel E.
# Luiz F.
# Laura M.
# Matheus L.
# Arthur D.
# Vagner A.
# Vitor Soares C.
# Andreia V.
# Clayton M.
# Clayton M.
# Hellen C.
# Humberto C.
# Juliana F.
# Rondinele S.
# Diego M.
# Isaac R.
# Marvin  B.
# Bruno Q.
# Matheus D.
# Vander G.
# Layson D.
# Vítor B.
# Juliana V.
# Claudia E.
# Alex D.
# João T.
# João Paulo M.
# Nina Bárbara d.
# Melissa M.
# Marcos M.
# Jerveson L.
# Juliana B.
# Samuel R.
# Roberto R.
# Analice S.
# João M.
# Nayara M.
# Rafael R.
# Thiago R.
# Marianna C.
# Yuri B.
# Clarson G.
# Lorena C.
# Mariana P.
# Mariana M.
# Caio T.
# Daniela O.
# Lucas V.
# Mauro J.
# Tafarel c.
# Bruna Regina B.
# Rafael A.
# Lorena M.
# Johnatan G.
# Fernando L.
# Hugo O.
# Silvio C.
# Isaias G.
# LUCAS MARIANO P.
# Mariana A.
# Jordi R.
# Laisa S.
# Laercio L.
# Hyan F.
# Paulo Afonso  B.
# Fernanda Z.
# Bruno C.
# Warlley Gonçalves d.
# Arthur M.
# Yago B.
# Marcello N.
# Marilia M.
# Marcos C.
# Letícia R.
# Isabela B.
# Raphael G.
# Clóvis N.
# Thays L.
# Tiago A.
# João Victor M.
# Victor Hugo O.
# Amanda L.
# Augusto G.
#
# Descriptive Terms: Manager
# ---------------------------------------------
# Maurilio C.
# Marcio G.
#
# Descriptive Terms:
# ------------------------------------------------------------------------------------
# Eric R.
# Henrique C.
# Renato R.
# Carlos F.
# Carlos F.
# LUIS L.
# Giovanna A.
# Alexandre G.
#
# Descriptive Terms: Sistemas
# ----------------------------------------------------------------
# Marcos Antonio O.
# Rodolfo M.
# Guilherme S.
# Rodrigo F.
# Paulo V.
# Mauricio D.
# Flavia B.
# Danilo N.
# Humberto C.
# Renan S.
# Diego M.
# Daniel T.
# Hiago P.
# Vítor B.
# Alex D.
# Vitor Bruno L.
# José I.
# Thiago A.
# Kayke M.
# Hugo O.
# Silvio C.
# Laercio L.
# Paulo Afonso  B.
# Rodrigo G.
#
# Descriptive Terms: Of, Operations
# ------------------------------------------------------------------
# Rodrigo S.
# JEANDERNEY F.
#
# Descriptive Terms: Assistente
# -------------------------------------------------------
# Mayara M.
# Isabel Cristina  d.
# Lucas G.
# Rivana B.
#
# Descriptive Terms:
# -------------------------------------------------------------------
# Eduardo M.
# Luzidalva L.
# Vinícius R.
#
# Descriptive Terms: Software, Engenheiro, de
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Lourenço R.
# Lourenço R.
# Guilherme S.
# Túlio M.
# Vandré L.
# Ricardo B.
# Ricardo B.
# Alan F.
# Danniel F.
# Larissa A.
# Paulo Henrique M.
# Ítalo Louis A.
# Paula B.
# Lucas T.
# Luan  D.
# Felipe Amâncio D.
# Matheus J.
# Henrique M.
# Lucas M.
# João Augusto M.
#
# Descriptive Terms: Engenheiro, de
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Lourenço R.
# Lourenço R.
# Guilherme S.
# Vandré L.
# Ricardo B.
# Ricardo B.
# Alan F.
# Danniel F.
# Pedro  E.
# Larissa A.
# Paulo Henrique M.
# Ítalo Louis A.
# Paula B.
# Lucas T.
# Luan  D.
# Felipe Amâncio D.
# Matheus J.
# Henrique M.
# Lucas M.
# João Augusto M.
# Maressa S.
#
# Descriptive Terms:
# --------------------------------------------------------------------------------------------------------------
# Theodore T (Bear) M.
# Rodolfo M.
# Renato Dalmo L.
# Rodrigo F.
# Paulo V.
# Nathália R.
# Edilene C.
# Fabiano D.
# Mônica d.
# Jerry G.
# Fernanda B.
# Jakeline B.
# Kele M.
# Warla  L.
# Danilo N.
# Lucas R.
# Thais R.
# Diego H.
# Tarcisio M.
# Rafael B.
# Arlindo J.
# Matheus F.
# Gabriel E.
# Luiz F.
# Laura M.
# Matheus L.
# Arthur D.
# Vagner A.
# Vitor Soares C.
# Andreia V.
# Clayton M.
# Clayton M.
# Humberto C.
# Juliana F.
# Rondinele S.
# Diego M.
# Isaac R.
# Marvin  B.
# Bruno Q.
# Matheus D.
# Vander G.
# Layson D.
# Vítor B.
# Juliana V.
# Claudia E.
# Alex D.
# João T.
# João Paulo M.
# Nina Bárbara d.
# Melissa M.
# Marcos M.
# Jerveson L.
# Juliana B.
# Samuel R.
# Roberto R.
# Analice S.
# João M.
# Nayara M.
# Rafael R.
# Thiago R.
# Marianna C.
# Yuri B.
# Clarson G.
# Lorena C.
# Mariana P.
# Mariana M.
# Caio T.
# Daniela O.
# Lucas V.
# Mauro J.
# Tafarel c.
# Bruna Regina B.
# Rafael A.
# Lorena M.
# Johnatan G.
# Fernando L.
# Hugo O.
# Silvio C.
# Isaias G.
# LUCAS MARIANO P.
# Mariana A.
# Jordi R.
# Laisa S.
# Laercio L.
# Hyan F.
# Paulo Afonso  B.
# Fernanda Z.
# Bruno C.
# Warlley Gonçalves d.
# Arthur M.
# Yago B.
# Marcello N.
# Marilia M.
# Marcos C.
# Letícia R.
# Isabela B.
# Raphael G.
# Clóvis N.
# Thays L.
# Tiago A.
# João Victor M.
# Victor Hugo O.
# Amanda L.
# Augusto G.
#
# Descriptive Terms: Engenheiro, de
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Lourenço R.
# Lourenço R.
# Vandré L.
# Ricardo B.
# Ricardo B.
# Alan F.
# Danniel F.
# Pedro  E.
# Paulo Henrique M.
# Ítalo Louis A.
# Paula B.
# Lucas T.
# Luan  D.
# Felipe Amâncio D.
# Matheus J.
# Lucas M.
# João Augusto M.
# Maressa S.
#
# Descriptive Terms: End
# --------------------------------------------------------
# Lourenço R.
# Dione Munir S.
# Bruno C.
# Cristiano L.
# Flávio A.
# José Lemes N.
#
# Descriptive Terms: Software
# ----------------------------------------------
# Renato R.
# Weverton L.
# Carlos M.
# Elner R.
# Ruth C.
#
# Descriptive Terms: People
# ------------------------------------------
# Gustavo D.
# Joeudes A.
#
# Descriptive Terms:
# ---------------------------------------
# Eder B.
# Marcelo S.
# Pablo Henrique S.
# Matheus M.
# Filipe F.
#
# Descriptive Terms: Sócio
# -------------------------------------------------------------
# Leonardo B.
# Matheus M.
# Diamond  C.
#
# Descriptive Terms: negócios, em
# ----------------------------------------------------------------------
# Edilene C.
# Thiago R.
#
# Descriptive Terms: Service, Lea
# ----------------------------------------------------------
# Luismar C.
# Pablo P.
#
# Descriptive Terms: Programador
# ----------------------------------------------------------------------------------------------
# Júlio César S.
# Cristiano L.
# Arthur M.
# Alessandro A.
#
# Descriptive Terms: Owner
# --------------------------------------
# Pablo Henrique S.
# Jean S.
# Fernando F.
# Thayná O.
#
# Descriptive Terms: Senior, Developer, React
# -------------------------------------------------------------------------------
# Gustavo G.
# Gustavo G.
#
# Descriptive Terms:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Rodolfo M.
# Jorge Eurípedes d.
# Renato Dalmo L.
# Rodrigo F.
# Paulo V.
# Nathália R.
# Edilene C.
# Fabiano D.
# Mônica d.
# Bruno Garcia d.
# Marcelo S.
# Fernanda B.
# Kele M.
# Lucas Arruda V.
# Warla  L.
# Danilo N.
# Lucas R.
# Thais R.
# Diego H.
# Tarcisio M.
# Rafael B.
# Arlindo J.
# Matheus F.
# Gabriel E.
# Luiz F.
# Alexandre R.
# Laura M.
# Matheus L.
# Arthur D.
# Vitor Soares C.
# Andreia V.
# Clayton M.
# Clayton M.
# Hugo A.
# Humberto C.
# Juliana F.
# Rondinele S.
# Diego M.
# Isaac R.
# Marvin  B.
# Bruno Q.
# Marco Tulio B.
# Matheus D.
# Vander G.
# Layson D.
# Vítor B.
# Juliana V.
# Claudia E.
# Alex D.
# Dario Soares N.
# João T.
# João Paulo M.
# Nina Bárbara d.
# Melissa M.
# Marcos M.
# Juliana B.
# Samuel R.
# Roberto R.
# Analice S.
# João M.
# Nayara M.
# Rafael R.
# Thiago R.
# Marianna C.
# Yuri B.
# Clarson G.
# Lorena C.
# Mariana P.
# Mariana M.
# Caio T.
# Daniela O.
# Lucas V.
# Mauro J.
# Tafarel c.
# Bruna Regina B.
# Rafael A.
# Lorena M.
# Johnatan G.
# Helton J.
# Fernando L.
# Hugo O.
# Silvio C.
# Isaias G.
# LUCAS MARIANO P.
# Mariana A.
# Jordi R.
# Laisa S.
# Laercio L.
# Hyan F.
# Paulo Afonso  B.
# Fernanda Z.
# Bruno C.
# Warlley Gonçalves d.
# Arthur M.
# Yago B.
# Marcello N.
# Marilia M.
# Letícia R.
# Isabela B.
# Raphael G.
# Clóvis N.
# Thays L.
# Tiago A.
# João Victor M.
# Victor Hugo O.
# Amanda L.
# Augusto G.
#
# Descriptive Terms:
# ---------------------------------------------------------------------
# Gustavo G.
# Victor d.
# Bruno R.
#
# Descriptive Terms: Operações
# ---------------------------------------------------------------------------------------------
# Henrique C.
# Maria Rita M.
# Davi C.
# Davi C.
#
# Descriptive Terms: end
# -------------------------------
# Ricardo B.
# Danniel F.
# Danniel F.
# Thiago C.
# Matheus J.
# Matheus J.
#
# Descriptive Terms: Analista
# -------------------------------------------------------------------------------------
# Rodolfo M.
# Renato Dalmo L.
# Rodrigo F.
# Paulo V.
# Nathália R.
# Edilene C.
# Fabiano D.
# Mônica d.
# Fernanda B.
# Kele M.
# Warla  L.
# Danilo N.
# Lucas R.
# Thais R.
# Diego H.
# Tarcisio M.
# Rafael B.
# Arlindo J.
# Matheus F.
# Gabriel E.
# Luiz F.
# Laura M.
# Matheus L.
# Arthur D.
# Vitor Soares C.
# Andreia V.
# Clayton M.
# Clayton M.
# Humberto C.
# Juliana F.
# Rondinele S.
# Diego M.
# Isaac R.
# Marvin  B.
# Bruno Q.
# Matheus D.
# Vander G.
# Layson D.
# Vítor B.
# Juliana V.
# Claudia E.
# Alex D.
# João T.
# João Paulo M.
# Nina Bárbara d.
# Melissa M.
# Marcos M.
# Juliana B.
# Samuel R.
# Roberto R.
# Analice S.
# João M.
# Nayara M.
# Rafael R.
# Thiago R.
# Marianna C.
# Yuri B.
# Clarson G.
# Lorena C.
# Mariana P.
# Mariana M.
# Caio T.
# Daniela O.
# Lucas V.
# Mauro J.
# Tafarel c.
# Bruna Regina B.
# Camila A.
# Rafael A.
# Lorena M.
# Johnatan G.
# Fernando L.
# Hugo O.
# Silvio C.
# Isaias G.
# LUCAS MARIANO P.
# Mariana A.
# Jordi R.
# Laisa S.
# Laercio L.
# Hyan F.
# Paulo Afonso  B.
# Fernanda Z.
# Bruno C.
# Warlley Gonçalves d.
# Daniella S.
# Arthur M.
# Yago B.
# Marcello N.
# Marilia M.
# Letícia R.
# Isabela B.
# Raphael G.
# Clóvis N.
# Thays L.
# Tiago A.
# João Victor M.
# Victor Hugo O.
# Amanda L.
# Augusto G.
#
# Descriptive Terms: Engenheiro
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Vandré L.
# Ricardo B.
# Ricardo B.
# Alan F.
# Danniel F.
# Weverton L.
# Paulo Henrique M.
# Ítalo Louis A.
# Paula B.
# Lucas T.
# Felipe A.
# Luan  D.
# Felipe Amâncio D.
# Jeias S.
# Matheus J.
# Lucas M.
# João Augusto M.
# Maressa S.
#
# Descriptive Terms: Software, Engenheiro, de
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Vandré L.
# Ricardo B.
# Ricardo B.
# Alan F.
# Danniel F.
# Pedro  E.
# Paulo Henrique M.
# Ítalo Louis A.
# Paula B.
# Lucas T.
# Luan  D.
# Felipe Amâncio D.
# Matheus J.
# Lucas M.
# João Augusto M.
#
# Descriptive Terms: sistemas
# -----------------------------------------------------------
# Thais R.
# Diego H.
# Gabriel E.
# Matheus L.
# Luzidalva L.
# Adauto A.
# João T.
# João M.
# Rafael R.
# Lucas V.
# Warlley Gonçalves d.
# Marcos C.
#
# Descriptive Terms: Programador
# -----------------------------------------------------------------------------
# Cristiano L.
# Arthur M.
# Alessandro A.
#
# Descriptive Terms:
# ----------------------------------------------------------------------------------------------------------------------------
# Elediane Micheli B.
# Eric R.
# Henrique C.
# Rodrigo M.
# Renato R.
# Luis J.
# Carlos F.
# LUIS L.
# Johnatan G.
# Giovanna A.
# Alexandre G.
#
# Descriptive Terms: Planejamento
# ---------------------------------------------------------------
# Arlindo J.
# Laisa S.
#
# Descriptive Terms: nador
# -----------------------------------------------
# Vinicius M.
# Fábio C.
# Anderson R.
# .Emanuel P.
# Helder L.
# Marcos Marques A.
# Vanderlei G.
# Clayton M.
# Mariana D.
# Raphael M.
# Meline M.
#
# Descriptive Terms: vendas
# ------------------------------------------------------
# LUIS L.
# Anderson L.
#
# Descriptive Terms: Analista, de
# -----------------------------------------------------------------------------------------------------
# Marcos Antonio O.
# Guilherme S.
# Mauricio D.
# Flavia B.
# Daniel S.
# Arthur D.
# Renan S.
# Daniel T.
# Hiago P.
# Vitor Bruno L.
# José I.
# Thiago A.
# Kayke M.
# Rodrigo G.
#
# Descriptive Terms: suporte
# ------------------------------------------
# Marcos M.
# Mariana A.
# Victor Hugo O.
# Amanda L.
#
# Descriptive Terms: Front
# -------------------------------------------
# Lourenço R.
# Lourenço R.
# Lourenço R.
# Douglas F.
# Dione Munir S.
# Bruno C.
# José Lemes N.
#
# Descriptive Terms: Professor
# -------------------------------------------------
# Marcelo R.
# Vitor C.
# Igor M.
#
# Descriptive Terms: Analyst
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Jorge Eurípedes d.
# Marcelo S.
# Brenner M.
# Ramiro S.
# Marco Tulio B.
# Breno S.
# Lucas B.
# Anderson A.
# Herculano C.
# Matheus S.
# Lucas R.
#
# ...
# Lucas V.
# Mauro J.
# Tafarel c.
# Bruna Regina B.
# Rafael A.
# Lorena M.
# Johnatan G.
# Fernando L.
# Hugo O.
# Silvio C.
# Isaias G.
# LUCAS MARIANO P.
# Mariana A.
# Jordi R.
# Laisa S.
# Laercio L.
# Hyan F.
# Paulo Afonso  B.
# Fernanda Z.
# Bruno C.
# Warlley Gonçalves d.
# Arthur M.
# Yago B.
# Marcello N.
# Marilia M.
# Marcos C.
# Letícia R.
# Isabela B.
# Raphael G.
# Clóvis N.
# Thays L.
# Tiago A.
# João Victor M.
# Victor Hugo O.
# Amanda L.
# Augusto G.
#
# Descriptive Terms: Auxiliar
# ---------------------------------------------------
# Rodrigo A.
# Wagner S.
#
# Descriptive Terms: Operações
# ----------------------------------------------------
# Henrique C.
# Maria Rita M.
#
# Descriptive Terms: TI, em
# ----------------------------------------------------------------
# Edilene C.
# Lisandra R.
#
# Descriptive Terms: r
# -----------------------------------------------------------
# Thiago Caetano C.
# Thiago Caetano C.
# Eder B.
# Eder B.
# Eder B.
# Eder B.
# Francisco C.
# Wesley P.
# Henrique P.
# Henrique P.
# Rita de Cássia C.
# José Pedro D.
# Frederico A.
# LIGIA S.
# Priscila G.
# Lorena B.
# Nilson B.
# Luismar C.
# Gustavo F.
# Pablo P.
# Lilian Christina O.
# Diego V.
# Gustavo G.
# Gustavo G.
# Paulo Rogério L.
# Thiego R.
# Filipe F.
# Filipe F.
# Lorena L.
# Lilian D.
# IT2YOU P.
# Guilherme C.
# 💳 Susy Nunes O.
# Lorena M.
#
# Descriptive Terms: Analista
# -----------------------------------------------
# Rodolfo M.
# Renato Dalmo L.
# Rodrigo F.
# Paulo V.
# Nathália R.
# Edilene C.
# Fabiano D.
# Mônica d.
# Fernanda B.
# Kele M.
# Warla  L.
# Danilo N.
# Lucas R.
# Thais R.
# Diego H.
# Tarcisio M.
# Rafael B.
# Arlindo J.
# Matheus F.
# Gabriel E.
# Luiz F.
# Laura M.
# Matheus L.
# Arthur D.
# Vitor Soares C.
# Andreia V.
# Clayton M.
# Clayton M.
# Humberto C.
# Juliana F.
# Rondinele S.
# Diego M.
# Isaac R.
# Marvin  B.
# Bruno Q.
# Matheus D.
# Vander G.
# Layson D.
# Vítor B.
# Alessandro O.
# Juliana V.
# Claudia E.
# Alex D.
# João T.
# João Paulo M.
# Nina Bárbara d.
# Melissa M.
# Marcos M.
# Juliana B.
# Samuel R.
# Roberto R.
# Analice S.
# João M.
# Nayara M.
# Rafael R.
# Thiago R.
# Marianna C.
# Yuri B.
# Clarson G.
# Lorena C.
# Mariana P.
# Mariana M.
# Caio T.
# Daniela O.
# Lucas V.
# Mauro J.
# Tafarel c.
# Bruna Regina B.
# Rafael A.
# Lorena M.
# Johnatan G.
# Fernando L.
# Hugo O.
# Silvio C.
# Isaias G.
# LUCAS MARIANO P.
# Mariana A.
# Jordi R.
# Laisa S.
# Laercio L.
# Hyan F.
# Paulo Afonso  B.
# Fernanda Z.
# Bruno C.
# Warlley Gonçalves d.
# Arthur M.
# Yago B.
# Marcello N.
# Marilia M.
# Letícia R.
# Isabela B.
# Raphael G.
# Clóvis N.
# Thays L.
# Tiago A.
# João Victor M.
# Victor Hugo O.
# Amanda L.
# Augusto G.
#
# Descriptive Terms: Software, Engenheiro, de
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Ricardo B.
# Ricardo B.
# Alan F.
# Danniel F.
# Pedro  E.
# Ítalo Louis A.
# Lucas T.
# Felipe Amâncio D.
# Matheus J.
# Lucas M.
# João Augusto M.
#
# Descriptive Terms: Executive, Chief, Officer
# --------------------------------------------------------------------------------------------------------------------------------------
# Eder B.
# Eder B.
# Eder B.
# Maria Emília D.
# Diego D.
# Alexandre Augusto A.
# Rafael M.
#
# Descriptive Terms: Executive, Chief, Officer
# ---------------------------------------------------------------------------------------------------
# Eder B.
# Eder B.
# Maria Emília D.
# Diego D.
# Alexandre Augusto A.
# Rafael M.
#
# Descriptive Terms: Pleno
# ------------------------------------------
# Vítor B.
# Johnatan G.
# Paulo Afonso  B.
#
# Descriptive Terms: BI
# ---------------------------------------------------------
# Elediane Micheli B.
# Henrique C.
# Johnatan G.
#
# Descriptive Terms: Programador
# ---------------------------------------------------------
# Cristiano L.
# Arthur M.
#
# Descriptive Terms: Sênior
# ---------------------------------------------------------------------------
# Graziele P.
# Fabiano D.
# Rondinele S.
#
# Descriptive Terms: sistemas
# -------------------------------------------
# Thais R.
# Diego H.
# Gabriel E.
# Matheus L.
# Luzidalva L.
# Adauto A.
# João T.
# Rafael R.
# Lucas V.
# Warlley Gonçalves d.
# Marcos C.
#
# Descriptive Terms: Encarregado
# ---------------------------------------------------
# Rodrigo P.
# Alysson m.
#
# Descriptive Terms: Software, Engenheiro, de
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Ricardo B.
# Ricardo B.
# Alan F.
# Danniel F.
# Pedro  E.
# Ítalo Louis A.
# Lucas T.
# Matheus J.
# Lucas M.
# João Augusto M.
#
# Descriptive Terms: Software, Engenheiro, de
# ---------------------------------------------------------------------------------------------------------------------------------------------------
# Ricardo B.
# Ricardo B.
# Alan F.
# Pedro  E.
# Ítalo Louis A.
# Lucas T.
# Lucas M.
# João Augusto M.
#
# Descriptive Terms: Sócio
# ------------------------------------------------------
# Leonardo B.
# Diamond  C.
#
# Descriptive Terms: r
# ---------------------------------------
# Henrique P.
# Henrique P.
# Rita de Cássia C.
# LIGIA S.
# Nilson B.
# IT2YOU P.
# Guilherme C.
#
# Descriptive Terms: Software, Engenheiro, de
# ----------------------------------------------------------------------------------------------------------------------
# Ricardo B.
# Ricardo B.
# Alan F.
# Pedro  E.
# Ítalo Louis A.
# Lucas T.
#
# Descriptive Terms: Informações, Gerenciais
# ---------------------------------------------------------------------------------------
# Graziele P.
# Vander G.
#
# Descriptive Terms: sistemas
# -------------------------------------------------
# Jerry G.
# Thais R.
# Diego H.
# Gabriel E.
# Matheus L.
# Adauto A.
# João T.
# Rafael R.
# Lucas V.
# Warlley Gonçalves d.
# Marcos C.
#
# Descriptive Terms: Executive, Chief, Co, Officer
# --------------------------------------------------------------------------
# Eder B.
# Diego D.
#
# Descriptive Terms: Supervisor
# -------------------------------------------------------
# Djone machado M.
# Rafael B.
# Fabio P.
# Arthur P.'. de G.
#
# Descriptive Terms:
# ---------------------------------------------------------------------------------------------
# Weverton L.
# Felipe A.
# Leonardo B.
# Eurípedes C.
# Jeias S.
# Alyne M.
#
# Descriptive Terms: Engenheiro
# ----------------------------------------------------
# Weverton L.
# Felipe A.
# Eurípedes C.
# Jeias S.
#
# Descriptive Terms: Co
# -----------------------------
# Eder B.
# Pablo Henrique S.
# Paulo Rogério L.
# Filipe F.
#
# Descriptive Terms: Business
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Jorge Eurípedes d.
# Bruno Garcia d.
# Marcelo S.
# Lucas Arruda V.
# Hugo A.
# Marco Tulio B.
# Dario Soares N.
# Helton J.
#
# Descriptive Terms: Junior
# ---------------------------------------------------
# Hellen C.
# Thais C.
#
# Descriptive Terms: Software, Engenheiro, de
# --------------------------------------------------------------------------------
# Ricardo B.
# Ricardo B.
# Alan F.
# Ítalo Louis A.
# Lucas T.
#
# Descriptive Terms: Developer
# -----------------------------------------------------------
# Henrique P.
# Henrique P.
# Rita de Cássia C.
# LIGIA S.
# Dione Munir S.
# Nilson B.
# Pedro G.
# Guilherme C.
# José Lemes N.
#
# Descriptive Terms: Informação, da, Tecnologia
# -----------------------------------------------------------------------------
# Maria Fernanda C.
# Nina Bárbara d.
#
# Descriptive Terms: Executivo
# ------------------------------------------
# Daniel A.
# Marcos Rodrigo S.
#
# Descriptive Terms: Master, Scrum
# ------------------------------------------------------------
# Jerry G.
# Gil Victor Teixeira P.
#
# Descriptive Terms: Senior
# ----------------------------------------------------------------
# Carlos Eduardo Alves S.
# Rodrigo M.
# Isaias G.
#
# Descriptive Terms: Business
# ------------------------------------------------------------------------------------------------------------------------------------------
# Jorge Eurípedes d.
# Marcelo S.
# Hugo A.
# Marco Tulio B.
# Matheus S.
# Lucas R.
#
# Descriptive Terms: Analyst, IT
# --------------------------------------------------------------------------------------------------------------------
# Lucas B.
# Lucas B.
# Anderson A.
# Matheus S.
#
# Descriptive Terms: Analyst
# -----------------------------------------------------------------------------------------------------------------
# Jorge Eurípedes d.
# Marcelo S.
# Anderson A.
# Matheus S.
# Lucas R.
#
# Descriptive Terms: Talentos, Humanos
# ----------------------------------------------------------
# Mônica d.
# Vanderlei G.
# Juliana M.
# Kriscia M.
# Melissa M.
#
# Descriptive Terms: Developer
# ----------------------------------------------
# Dione Munir S.
# Pedro G.
# José Lemes N.
#
# Descriptive Terms: Intelligence, Business
# -------------------------------------------------------------------------------------------------------------------------
# Jorge Eurípedes d.
# Bruno Garcia d.
# Marcelo S.
# Hugo A.
#
# Descriptive Terms: Controle, Planejamento, e
# --------------------------------------------------------------------------------------------
# Nayara C.
# Pablo R.
#
# Descriptive Terms: Coor
# ---------------------------------------------
# Vinicius M.
# Fábio C.
# Jerry G.
# Anderson R.
# .Emanuel P.
# Helder L.
# Marcos Marques A.
# Laís M.
# Lara L.
# Vanderlei G.
# Fernanda F.
# Clayton M.
# Camila T.
# Mariana D.
# Fernanda B.
# Monique B.
# Raphael M.
# Cléver L.
# Meline M.
#  Hingrid Therèse R.
#
# Descriptive Terms: Consultor
# -------------------------------------------------
# Ricardo F.
# Renato R.
# Carlos F.
# LUIS L.
# Giovanna A.
# Alexandre G.
#
# Descriptive Terms: Intelligence, Business
# --------------------------------------------------------------------------------------
# Jorge Eurípedes d.
# Bruno Garcia d.
# Marcelo S.
#
# Descriptive Terms: Administrativo, Auxiliar
# -----------------------------------------------------------------------------------
# Rodrigo A.
# Marcos T.
#
# Descriptive Terms: Senior
# ---------------------------------------------
# Rodrigo M.
# Isaias G.
#
# Descriptive Terms:
# -----------------------------------------------------------------------------------------------------
# Henrique C.
# Henrique C.
# Davi C.
# Davi G.
#
# Descriptive Terms:
# ---------------------------------------------------------------------------------
# Rodolfo M.
# Renato Dalmo L.
# Rodrigo F.
# Paulo V.
# Nathália R.
# Edilene C.
# Fabiano D.
# Mônica d.
# Jerry G.
# Fernanda B.
# Kele M.
# Warla  L.
# Danilo N.
# Lucas R.
# Thais R.
# Diego H.
# Tarcisio M.
# Rafael B.
# Arlindo J.
# Matheus F.
# Gabriel E.
# Luiz F.
# Laura M.
# Matheus L.
# Arthur D.
# Vitor Soares C.
# Andreia V.
# Clayton M.
# Clayton M.
# Humberto C.
# Juliana F.
# Rondinele S.
# Diego M.
# Isaac R.
# Marvin  B.
# Bruno Q.
# Matheus D.
# Vander G.
# Layson D.
# Vítor B.
# Juliana V.
# Claudia E.
# Alex D.
# João T.
# João Paulo M.
# Nina Bárbara d.
# Melissa M.
# Marcos M.
# Juliana B.
# Samuel R.
# Roberto R.
# Analice S.
# João M.
# Nayara M.
# Rafael R.
# Thiago R.
# Marianna C.
# Yuri B.
# Clarson G.
# Lorena C.
# Mariana P.
# Mariana M.
# Caio T.
# Daniela O.
# Lucas V.
# Mauro J.
# Tafarel c.
# Bruna Regina B.
# Rafael A.
# Lorena M.
# Johnatan G.
# Fernando L.
# Hugo O.
# Silvio C.
# Isaias G.
# LUCAS MARIANO P.
# Mariana A.
# Jordi R.
# Laisa S.
# Laercio L.
# Hyan F.
# Paulo Afonso  B.
# Fernanda Z.
# Bruno C.
# Warlley Gonçalves d.
# Arthur M.
# Yago B.
# Marcello N.
# Marilia M.
# Marcos C.
# Letícia R.
# Isabela B.
# Raphael G.
# Clóvis N.
# Vinícius R.
# Thays L.
# Tiago A.
# João Victor M.
# Victor Hugo O.
# Amanda L.
# Augusto G.
#
# Descriptive Terms: Consultor
# --------------------------------------------------------------------
# Rodrigo M.
# Renato R.
# Luis J.
# Carlos F.
# LUIS L.
# Giovanna A.
# Alexandre G.
#
# Descriptive Terms:
# ----------------------------------------------------------
# Salger O.
# Renato G.
# Lucas C.
# Gustavo B.
# Gil Victor Teixeira P.
# Paulo S.
#
# Descriptive Terms: Consultor
# ---------------------------------------------
# Rodrigo M.
# Renato R.
# Carlos F.
# LUIS L.
# Giovanna A.
# Alexandre G.
#
# Descriptive Terms: Analyst, Business
# ------------------------------------------------------------------------
# Jorge Eurípedes d.
# Marcelo S.
# Lucas R.
#
# Descriptive Terms: Diretor
# --------------------------------------------
# Genivaldo O.
# Daniel R.
# Alan Á.
# Guilherme M.
# Jair F.
# Pro D.
#
# Descriptive Terms: Front
# ------------------------------------------
# Lourenço R.
# Lourenço R.
# Lourenço R.
# Douglas F.
# Dione Munir S.
# Cristiano L.
# José Lemes N.
#
# Descriptive Terms: BI
# ----------------------------------------
# Henrique C.
# Johnatan G.
#
# Descriptive Terms: pós
# -----------------------------------------
# Giordanni d.
# Giordanni d.
#
# Descriptive Terms: Analista
# ------------------------------------------------
# Marcos Antonio O.
# Rodolfo M.
# Renato Dalmo L.
# Guilherme S.
# Rodrigo F.
# Paulo V.
# Nathália R.
# Edilene C.
# Fabiano D.
# Mônica d.
# Mauricio D.
# Flavia B.
# Fernanda B.
# Kele M.
# Warla  L.
# Danilo N.
# Lucas R.
# Thais R.
# Diego H.
# Tarcisio M.
# Rafael B.
# Arlindo J.
# Matheus F.
# Gabriel E.
# Luiz F.
# Laura M.
# Matheus L.
# Arthur D.
# Vitor Soares C.
# Andreia V.
# Clayton M.
# Clayton M.
# Humberto C.
# Renan S.
# Juliana F.
# Rondinele S.
# Diego M.
# Daniel T.
# Hiago P.
# Isaac R.
# Marvin  B.
# Bruno Q.
# Matheus D.
# Vander G.
# Layson D.
# Vítor B.
# Juliana V.
# Claudia E.
# Alex D.
# João T.
# João Paulo M.
# Nina Bárbara d.
# Melissa M.
# Marcos M.
# Juliana B.
# Samuel R.
# Roberto R.
# Analice S.
# Vitor Bruno L.
# José I.
# João M.
# Nayara M.
# Rafael R.
# Thiago R.
# Marianna C.
# Yuri B.
# Clarson G.
# Lorena C.
# Mariana P.
# Mariana M.
# Thiago A.
# Caio T.
# Daniela O.
# Lucas V.
# Mauro J.
# Tafarel c.
# Bruna Regina B.
# Rafael A.
# Lorena M.
# Johnatan G.
# Fernando L.
# Kayke M.
# Hugo O.
# Silvio C.
# Isaias G.
# LUCAS MARIANO P.
# Mariana A.
# Jordi R.
# Laisa S.
# Laercio L.
# Hyan F.
# Paulo Afonso  B.
# Fernanda Z.
# Bruno C.
# Rodrigo G.
# Warlley Gonçalves d.
# Arthur M.
# Yago B.
# Marcello N.
# Marilia M.
# Letícia R.
# Isabela B.
# Raphael G.
# Clóvis N.
# Thays L.
# Tiago A.
# João Victor M.
# Victor Hugo O.
# Amanda L.
# Augusto G.
#
# Descriptive Terms: TI
# ------------------------------------
# Bruno M.
# Edilene C.
# Edgar Zattar D.
# Rita M.
#
# Descriptive Terms: Analista
# ---------------------------------------------------------
# Rodolfo M.
# Renato Dalmo L.
# Rodrigo F.
# Paulo V.
# Nathália R.
# Edilene C.
# Fabiano D.
# Mônica d.
# Fernanda B.
# Kele M.
# Warla  L.
# Danilo N.
# Lucas R.
# Thais R.
# Diego H.
# Tarcisio M.
# Rafael B.
# Arlindo J.
# Matheus F.
# Gabriel E.
# Luiz F.
# Laura M.
# Matheus L.
# Arthur D.
# Vitor Soares C.
# Andreia V.
# Clayton M.
# Clayton M.
# Humberto C.
# Juliana F.
# Rondinele S.
# Diego M.
# Isaac R.
# Marvin  B.
# Bruno Q.
# Matheus D.
# Vander G.
# Layson D.
# Vítor B.
# Juliana V.
# Claudia E.
# Alex D.
# João T.
# João Paulo M.
# Nina Bárbara d.
# Melissa M.
# Marcos M.
# Juliana B.
# Samuel R.
# Roberto R.
# Analice S.
# João M.
# Nayara M.
# Rafael R.
# Thiago R.
# Marianna C.
# Yuri B.
# Clarson G.
# Lorena C.
# Mariana P.
# Mariana M.
# Caio T.
# Daniela O.
# Lucas V.
# Mauro J.
# Tafarel c.
# Bruna Regina B.
# Rafael A.
# Lorena M.
# Johnatan G.
# Fernando L.
# Hugo O.
# Silvio C.
# Isaias G.
# LUCAS MARIANO P.
# Mariana A.
# Jordi R.
# Laisa S.
# Laercio L.
# Hyan F.
# Paulo Afonso  B.
# Fernanda Z.
# Bruno C.
# Warlley Gonçalves d.
# Daniella S.
# Arthur M.
# Yago B.
# Marcello N.
# Marilia M.
# Letícia R.
# Isabela B.
# Raphael G.
# Clóvis N.
# Thays L.
# Tiago A.
# João Victor M.
# Victor Hugo O.
# Amanda L.
# Augusto G.
#
# Descriptive Terms: Administrativo
# ----------------------------------------------------------------
#  Crênio Roberto S.
#  Crênio Roberto S.
# Rodrigo A.
#
# Descriptive Terms: Pesquisador
# -------------------------------------------------
# Giordanni d.
# Giordanni d.
#
# Descriptive Terms: Analista
# -----------------------------------------------
# Rodolfo M.
# Renato Dalmo L.
# Rodrigo F.
# Paulo V.
# Nathália R.
# Edilene C.
# Fabiano D.
# Mônica d.
# Jerry G.
# Fernanda B.
# Kele M.
# Warla  L.
# Danilo N.
# Lucas R.
# Thais R.
# Diego H.
# Tarcisio M.
# Rafael B.
# Arlindo J.
# Matheus F.
# Gabriel E.
# Luiz F.
# Laura M.
# Matheus L.
# Arthur D.
# Vitor Soares C.
# Andreia V.
# Clayton M.
# Clayton M.
# Humberto C.
# Juliana F.
# Rondinele S.
# Diego M.
# Isaac R.
# Marvin  B.
# Bruno Q.
# Matheus D.
# Vander G.
# Layson D.
# Vítor B.
# Juliana V.
# Claudia E.
# Alex D.
# João T.
# João Paulo M.
# Nina Bárbara d.
# Melissa M.
# Marcos M.
# Juliana B.
# Samuel R.
# Roberto R.
# Analice S.
# João M.
# Nayara M.
# Rafael R.
# Thiago R.
# Marianna C.
# Yuri B.
# Clarson G.
# Lorena C.
# Mariana P.
# Mariana M.
# Caio T.
# Daniela O.
# Lucas V.
# Mauro J.
# Tafarel c.
# Bruna Regina B.
# Rafael A.
# Lorena M.
# Johnatan G.
# Fernando L.
# Hugo O.
# Silvio C.
# Isaias G.
# LUCAS MARIANO P.
# Mariana A.
# Jordi R.
# Laisa S.
# Laercio L.
# Hyan F.
# Paulo Afonso  B.
# Fernanda Z.
# Bruno C.
# Warlley Gonçalves d.
# Arthur M.
# Yago B.
# Marcello N.
# Marilia M.
# Letícia R.
# Isabela B.
# Raphael G.
# Clóvis N.
# Thays L.
# Tiago A.
# João Victor M.
# Victor Hugo O.
# Amanda L.
# Augusto G.

# %% [markdown]
# ### Linkedin - Visualizando o agrupamento dos meus contatos por cargo

# %%
import os
import sys
import json
import webbrowser


class ComplexEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, complex):
             return [obj.real, obj.imag]
         # Let the base class default method raise the TypeError
        return json.JSONEncoder.default(self, obj)

HTML_TEMPLATE = 'dojo-tree.html'

data = {"label": "name", "temp_items": {}, "items": []}

clustered_contacts = cluster_contacts_by_title(CSV_FILE)

for titles in clustered_contacts:
    descriptive_terms = set(titles[0].split())
    for title in titles:
        descriptive_terms.intersection_update(set(title.split()))
    descriptive_terms = ', '.join(descriptive_terms)

    if descriptive_terms in data['temp_items']:
        data['temp_items'][descriptive_terms].extend([{'name': cc} for cc
                                                      in clustered_contacts[titles]])
    else:
        data['temp_items'][descriptive_terms] = [{'name': cc} for cc
                                                 in clustered_contacts[titles]]

for descriptive_terms in data['temp_items']:
    data['items'].append({"name": "%s (%s)" % (descriptive_terms,
                                               len(data['temp_items'][descriptive_terms]),),
                          "children": [i for i in
                                       data['temp_items'][descriptive_terms]]})

del data['temp_items']

# Open the template and substitute the data

if not os.path.isdir('out'):
    os.mkdir('out')

OUT = os.path.join('out', 'dojo-tree.html')

t = open(HTML_TEMPLATE).read()
f = open(OUT, 'w')
f.write(t % json.dumps(data, indent=4, cls=ComplexEncoder))


f.close()

webbrowser.open("file://" + os.path.join(os.getcwd(), OUT))
# Out:
# True
